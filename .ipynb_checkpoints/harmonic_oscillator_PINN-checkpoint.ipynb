# %%
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

# %%
import numpy as np
import scipy as sp
import math
import torch
import optuna
import torch.autograd as autograd
import matplotlib.pyplot as plt
import inspect
import textwrap

from typing import Callable
from torch import nn, optim
from sklearn.model_selection import KFold
from data_PINN import diffeq, create_trainig_test_set, create_trainig_validation_test_set

import torch.nn.functional as F

torch.use_deterministic_algorithms(True)

# %%
if torch.accelerator.is_available():
    device = torch.accelerator.current_accelerator().type
else:
    device = "cpu"

print(device)
# Out:
# cuda

# %% [markdown]
# ## Defining the differential equation
#
# We are using the differential equation of a harmonic oscillator:
#
# $m \frac{d^2 x}{dt^2} +kx = 0$

# %%
#Define the harmonic oscillator

def f(t,x,k):
    #write the function that is on the other side of the differential equation
    return -k*x

def differential_equation_1_order(t, x, k):
    dx_dt = f(t,x,k)
    return dx_dt

def differential_equation_2_order(t, X, k):
    #rewrite d^2x/dt^2 as dy/dt where y=dx/dt
    x, y = X
    dx_dt = y
    dy_dt = f(t,x,k)

    return [dx_dt, dy_dt]

# %% [markdown]
# # 1. First try

# %% [markdown]
# ## Generating datasets
#
# TODO: implement data generation with analytical solution

# %%
#define the harmonic oscillator class (which ode's, number of variables: x,y, number of arguments: k)
harmonic_osc = diffeq(differential_equation_2_order, 2, 1)

#create training and test datasets (which diffeq, timespan, how many timesteps, how many initial conditions (datasets with each 100 timepoints), fraction of test sets, which numerical method to compare, which device, random seed to create data)
train, test = create_trainig_test_set(harmonic_osc, (0, 10), 100, 1000, 0.3, "RK45", device=device, seed=0)

#note: device:cuda did not work

# %%
print(train["X"].shape)
print(train["y_tensor"][0:, 0:, 0].unsqueeze(-1).shape)
print(train["t_tensor"].shape)
print(train["args_tensor"].shape)
# Out:
# torch.Size([700, 100, 4])
# torch.Size([700, 100, 1])
# torch.Size([700, 100])
# torch.Size([700, 1])

# %%
class HarmonicModel(nn.Module):
    def __init__(self, n_in):
        super().__init__()
        self.linear = nn.Linear(in_features=n_in, out_features=32)
        self.linear2 = nn.Linear(32, 1)

    def forward(self, x):
        x = F.tanh(self.linear(x))
        x = self.linear2(x)
        return x

# Initiate the model
model = HarmonicModel(4).to(device)

# %%
def loss_PINN(y_pred, y_exp, x_00, x_01, t, k, N_f):
    mse_y = torch.mean((y_pred - y_exp)**2)

    t_f = torch.linspace(0, 100, steps=N_f).repeat(len(t), 1).unsqueeze(-1).requires_grad_(True).to(device)

    n_rep = int(N_f / len(y_exp[0]))

    k_f = k.unsqueeze(-1).repeat(1, n_rep, 1)
    x_00_f = x_00.unsqueeze(-1).repeat(1, n_rep, 1)
    x_01_f = x_01.unsqueeze(-1).repeat(1, n_rep, 1)

    X_f = torch.cat([k_f, x_00_f, x_01_f, t_f], dim=-1)
    
    y_f = model(X_f)
    x_t = autograd.grad(y_f, t_f,
                       grad_outputs=torch.ones_like(y_f),
                       create_graph=True, allow_unused=True)[0]
    
    x_tt = autograd.grad(x_t, t_f,
                        grad_outputs=torch.ones_like(x_t),
                        create_graph=True, allow_unused=True)[0]
    
    # Residual
    f_res = x_tt + k_f*y_f
    mse_f = torch.mean(f_res**2)

    return mse_y + mse_f

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 1000

for epoch in range(epochs):
    X = train["X"]
    y_exp = train["y_tensor"][0:, 0:, 0].to(device)
    y_pred = model(X).squeeze(-1)
    t = X[0:, 0:, 3]
    k = X[0:, 0:, 0]
    x_00 = X[0:, 0:, 1]
    x_01 = X[0:, 0:, 2]

    loss = loss_PINN(y_pred, y_exp, x_00, x_01, t, k, N_f=1000)

    optimizer.zero_grad()
    loss.backward()
    
    optimizer.step()

    if (epoch+1) % (int(epochs/10)) == 0:
        print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}')
# Out:
# Epoch 100/1000, Loss: 0.5824
# Epoch 200/1000, Loss: 0.4128
# Epoch 300/1000, Loss: 0.2319
# Epoch 400/1000, Loss: 0.1887
# Epoch 500/1000, Loss: 0.1269
# Epoch 600/1000, Loss: 0.1052
# Epoch 700/1000, Loss: 0.0928
# Epoch 800/1000, Loss: 0.0868
# Epoch 900/1000, Loss: 0.0757
# Epoch 1000/1000, Loss: 0.0699

# %%
model.eval()
X = test["X"]
y_exp = test["y_tensor"][0:, 0:, 0].to(device)
y_pred = model(X).squeeze(-1)
t = X[0:, 0:, 3]
k = X[0:, 0:, 0]
x_00 = X[0:, 0:, 1]
x_01 = X[0:, 0:, 2]
#print(T_pred_test)
test_loss = loss_PINN(y_pred, y_exp, x_00, x_01, t, k, N_f=100)
print(f"Test Loss: {test_loss.item():.4f}")
# Out:
# Test Loss: 0.0857

# %%
print(y_pred.shape)
y_pred.to("cpu")
test["t_tensor"].to("cpu")

n = 30
plt.scatter(test["t_tensor"][n], test["y_tensor"][n][0:, 0], label="True Data")
plt.plot(test["t_tensor"][n], y_pred.cpu().detach()[n], color="red", label="Predictions")
plt.legend()
plt.show()
# Out:
# torch.Size([300, 100])

# %% [markdown]
# # 2. Hyperparameter optimization using random search

# %% [markdown]
# ## Generating datasets

# %%
train2, validation2, test2 = create_trainig_validation_test_set(harmonic_osc, (0, 10), 100, 1000, [0.5, 0.2, 0.3], "RK45", device=device, seed=0)

# %%
print(train2["X"].shape)
print(validation2["X"].shape)
print(test2["X"].shape)
# Out:
# torch.Size([500, 100, 4])
# torch.Size([200, 100, 4])
# torch.Size([300, 100, 4])

# %% [markdown]
# ## Defining the model

# %% [markdown]
# A model receives the number of initial parameters n_i, the number of hidden layers n_layers, number of neurons per layer and the activation function.
#
# TODO: implement different number of neurons for each layer, coefficients for loss terms, learning rate

# %%
class HarmonicModel2(nn.Module):
    def __init__(self, n_in, n_layers, n_neurons, activation):
        super().__init__()
        layers = []
        act = {
            'tanh': nn.Tanh(),
            'sine': torch.sin,
            'gelu': nn.GELU(),
            'relu': nn.ReLU()
        }[activation]
        
        layers.append(nn.Linear(n_in, n_neurons))
        for _ in range(n_layers - 1):
            layers.append(nn.Linear(n_neurons, n_neurons))
        layers.append(nn.Linear(n_neurons, 1))
        
        self.layers = nn.ModuleList(layers)
        self.activation = act

    def forward(self, x):
        for layer in self.layers[:-1]:
            if callable(self.activation):  # sine special case
                x = self.activation(layer(x))
            else:
                x = self.activation(layer(x))
        return self.layers[-1](x)

# test model
model = HarmonicModel2(4, 2, 32, 'tanh').to(device)

# %%
def loss_PINN2(y_pred, y_exp, x_00, x_01, t, k, N_f):
    mse_y = torch.mean((y_pred - y_exp)**2)

    t_f = torch.linspace(0, 100, steps=N_f).repeat(len(t), 1).unsqueeze(-1).requires_grad_(True).to(device)

    n_rep = int(N_f / len(y_exp[0]))

    k_f = k.unsqueeze(-1).repeat(1, n_rep, 1)
    x_00_f = x_00.unsqueeze(-1).repeat(1, n_rep, 1)
    x_01_f = x_01.unsqueeze(-1).repeat(1, n_rep, 1)

    X_f = torch.cat([k_f, x_00_f, x_01_f, t_f], dim=-1)
    
    y_f = model(X_f)
    x_t = autograd.grad(y_f, t_f,
                       grad_outputs=torch.ones_like(y_f),
                       create_graph=True, allow_unused=True)[0]
    
    x_tt = autograd.grad(x_t, t_f,
                        grad_outputs=torch.ones_like(x_t),
                        create_graph=True, allow_unused=True)[0]
    
    # Residual
    f_res = x_tt + k_f*y_f
    mse_f = torch.mean(f_res**2)

    return mse_y + mse_f

# %%
def train_PINN2(model, lr, epochs, data):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    X = data["X"]
    y_exp = data["y_tensor"][0:, 0:, 0].to(device)

    for epoch in range(epochs):
        y_pred = model(X).squeeze(-1)
        t = X[0:, 0:, 3]
        k = X[0:, 0:, 0]
        x_00 = X[0:, 0:, 1]
        x_01 = X[0:, 0:, 2]
    
        loss = loss_PINN2(y_pred, y_exp, x_00, x_01, t, k, N_f=1000)
    
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()
    
        if (epoch+1) % (int(epochs/10)) == 0:
            print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}')

    return loss.item()

# %% [markdown]
# ## Optimizing hyperparemeters

# %%
#layers_i, neurons_i, ... = interval of randomized values
def rng_hparameters_search(n_trials, layers_i: tuple, neurons_i: tuple, activations_l: list, data, seed=0):
    result = []
    torch.manual_seed(seed)
    layers = torch.randint(layers_i[0], layers_i[-1], (n_trials,)).to(device)
    neurons = torch.randint(neurons_i[0], neurons_i[-1], (n_trials,)).to(device)
    activations_idx = torch.randint(0, len(activations_l), (n_trials,)).to(device)
    activations = [activations_l[i] for i in activations_idx]

    for i in range(n_trials):
        params = {
            'n_layers': layers[i],
            'n_neurons': neurons[i],
            'activation': activations[i]
        }

        model = HarmonicModel2(4, params['n_layers'].item(), params['n_neurons'].item(), params['activation']).to(device)
        final_loss = train_PINN2(model, 0.01, 100, data)
        result.append((params, final_loss))
    
    return result

# %%
n_trials = 1000
results = rng_hparameters_search(n_trials, (1, 10), (1, 100), ['tanh', 'sine', 'gelu', 'relu'], validation2, seed=0)

# %%
best_params, best_loss = min(results, key=lambda x: x[1])
print("\nBest configuration:")
print(best_params)
print(f"Final loss: {best_loss:.3e}")
# Out:
# Best configuration:
# {'n_layers': tensor(6, device='cuda:0'), 'n_neurons': tensor(60, device='cuda:0'), 'activation': 'sine'}
# Final loss: 1.515e-02

# %% [markdown]
# Best configuration:
# {'n_layers': tensor(6, device='cuda:0'), 'n_neurons': tensor(60, device='cuda:0'), 'activation': 'sine'}
# Final loss: 1.515e-02

# %% [markdown]
# ## Testing found hyperparameters

# %%
model_optimized = HarmonicModel2(4, 6, 60, 'sine').to(device)

# %%
# training
loss_last = train_PINN2(model_optimized, 0.01, 1000, train2)
# Out:
# Epoch 100/1000, Loss: 0.0248
# Epoch 200/1000, Loss: 0.0544
# Epoch 300/1000, Loss: 0.0216
# Epoch 400/1000, Loss: 0.0030
# Epoch 500/1000, Loss: 0.0036
# Epoch 600/1000, Loss: 0.0046
# Epoch 700/1000, Loss: 0.0109
# Epoch 800/1000, Loss: 0.0073
# Epoch 900/1000, Loss: 0.0020
# Epoch 1000/1000, Loss: 0.0017

# %%
# test dataset
model_optimized.eval()
X = test2["X"]
y_exp = test2["y_tensor"][0:, 0:, 0].to(device)
y_pred = model_optimized(X).squeeze(-1)
t = X[0:, 0:, 3]
k = X[0:, 0:, 0]
x_00 = X[0:, 0:, 1]
x_01 = X[0:, 0:, 2]
#print(T_pred_test)
test_loss = loss_PINN2(y_pred, y_exp, x_00, x_01, t, k, N_f=100)
print(f"Test Loss: {test_loss.item():.4f}")
# Out:
# Test Loss: 0.0109

# %%
print(y_pred.shape)
y_pred.to("cpu")
test2["t_tensor"].to("cpu")

n = 30
plt.scatter(test2["t_tensor"][n], test2["y_tensor"][n][0:, 0], label="True Data")
plt.plot(test2["t_tensor"][n], y_pred.cpu().detach()[n], color="red", label="Predictions")
plt.legend()
plt.show()
# Out:
# torch.Size([300, 100])

# %% [markdown]
# # 3. Hyperparameter optimization using Optuna

# %% [markdown]
# ## Generating datasets

# %%
train3, validation3, test3 = create_trainig_validation_test_set(harmonic_osc, (0, 10), 100, 1000, [0.5, 0.2, 0.3], "RK45", device=device, seed=0)

# %%
print(train3["X"].shape)
print(validation3["X"].shape)
print(test3["X"].shape)
# Out:
# torch.Size([500, 100, 4])
# torch.Size([200, 100, 4])
# torch.Size([300, 100, 4])

# %% [markdown]
# ## Defining the model

# %%
class HarmonicModel3(nn.Module):
    def __init__(self, n_in: int, n_hidden_layers: int, hidden_neurons: list, activation: str):
        super().__init__()
        layers = []
        act = {
            'tanh': nn.Tanh(),
            'sine': torch.sin,
            'gelu': nn.GELU(),
            'relu': nn.ReLU()
        }[activation]
        
        layers.append(nn.Linear(n_in, hidden_neurons[0]))
        for i in range(n_hidden_layers - 1):
            layers.append(nn.Linear(hidden_neurons[i], hidden_neurons[i+1]))
        layers.append(nn.Linear(hidden_neurons[-1], 1))
        
        self.layers = nn.ModuleList(layers)
        self.activation = act

    def forward(self, x):
        for layer in self.layers[:-1]:
            if callable(self.activation):  # sine special case
                x = self.activation(layer(x))
            else:
                x = self.activation(layer(x))
        return self.layers[-1](x)

# test model
model = HarmonicModel3(4, 5, [32, 16, 8, 4, 2], 'tanh').to(device)
model
# Out:
# HarmonicModel3(
#   (layers): ModuleList(
#     (0): Linear(in_features=4, out_features=32, bias=True)
#     (1): Linear(in_features=32, out_features=16, bias=True)
#     (2): Linear(in_features=16, out_features=8, bias=True)
#     (3): Linear(in_features=8, out_features=4, bias=True)
#     (4): Linear(in_features=4, out_features=2, bias=True)
#     (5): Linear(in_features=2, out_features=1, bias=True)
#   )
#   (activation): Tanh()
# )

# %%
def loss_PINN3(model, y_pred, y_exp, x_00, x_01, t, k, N_f, l_y, l_f):
    mse_y = torch.mean((y_pred - y_exp)**2)

    t_f = torch.linspace(0, 100, steps=N_f).repeat(len(t), 1).unsqueeze(-1).requires_grad_(True).to(device)

    n_rep = int(N_f / len(y_exp[0]))

    k_f = k.unsqueeze(-1).repeat(1, n_rep, 1)
    x_00_f = x_00.unsqueeze(-1).repeat(1, n_rep, 1)
    x_01_f = x_01.unsqueeze(-1).repeat(1, n_rep, 1)

    X_f = torch.cat([k_f, x_00_f, x_01_f, t_f], dim=-1)
    
    y_f = model(X_f)
    x_t = autograd.grad(y_f, t_f,
                       grad_outputs=torch.ones_like(y_f),
                       create_graph=True, allow_unused=True)[0]
    
    x_tt = autograd.grad(x_t, t_f,
                        grad_outputs=torch.ones_like(x_t),
                        create_graph=True, allow_unused=True)[0]
    
    # Residual
    f_res = x_tt + k_f*y_f
    mse_f = torch.mean(f_res**2)

    return l_y*mse_y + l_f*mse_f

# %%
def train_PINN3(model_class, model_args, n_splits, l_y, l_f, optimizer_class, lr, epochs, N_f, data, random_state=0, show_progress=False):
    """
    optimizer_class: e.g. optim.Adam or optim.SGD
    """
    X_full = data["X"]
    y_exp_full = data["y_tensor"][0:, 0:, 0].to(device)

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    fold_losses = []

    best_model = None
    best_loss = float("inf")

    #K-fold loop
    for fold_id, (train_idx, val_idx) in enumerate(kf.split(X_full)):
        if show_progress:
            print(f'-----Fold: {fold_id + 1}-----')
        
        X_train = X_full[train_idx].to(device)
        y_train = y_exp_full[train_idx]
        X_val = X_full[val_idx].to(device)
        y_val = y_exp_full[val_idx]

        #New model every fold
        model = model_class(*model_args).to(device)
        optimizer = optimizer_class(model.parameters(), lr=lr)

        #Training
        for epoch in range(epochs):
            model.train()
            
            y_pred = model(X_train).squeeze(-1)
            t = X_train[0:, 0:, 3]
            k = X_train[0:, 0:, 0]
            x_00 = X_train[0:, 0:, 1]
            x_01 = X_train[0:, 0:, 2]
        
            loss = loss_PINN3(model, y_pred, y_train, x_00, x_01, t, k, N_f, l_y, l_f)
        
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if (epoch+1) % (int(epochs/10)) == 0 and show_progress:
                print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item():.4f}')

        #Validation
        model.eval()
        #with torch.no_grad():
        y_pred_val = model(X_val).squeeze(-1)
        t_val = X_val[0:, 0:, 3]
        k_val = X_val[0:, 0:, 0]
        x00_val = X_val[0:, 0:, 1]
        x01_val = X_val[0:, 0:, 2]

        val_loss = loss_PINN3(model, y_pred_val, y_val, x00_val, x01_val, t_val, k_val, N_f, l_y, l_f).item()
        if show_progress:
            print(f'\tValidation loss = {val_loss}')

        #Track best model
        if val_loss < best_loss:
            best_loss = val_loss
            best_model = model

        #Free vram
        del model
        del optimizer
        torch.cuda.empty_cache()
        torch.cuda.synchronize()


    return best_model, best_loss

# %% [markdown]
# ### Testing previous best model

# %%
torch.cuda.empty_cache()

best_model, best_loss = train_PINN3(HarmonicModel3, 
                                    (4, 6, [60, 60, 60, 60, 60, 60], 'sine'), 
                                    n_splits=5,
                                    l_y=1,
                                    l_f=1,
                                    optimizer_class=torch.optim.Adam, 
                                    lr=0.01, 
                                    epochs=1000, 
                                    N_f=100, 
                                    data=train3, 
                                    random_state=0,
                                    show_progress=True
                                   )
# Out:
# -----Fold: 1-----
# /home/izpodperda/University/Master/MachineLearning/Project/Machine-learning-project/.venv/lib/python3.12/site-packages/torch/autograd/graph.py:829: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:179.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 100/1000, Loss: 0.0543
# Epoch 200/1000, Loss: 0.0142
# Epoch 300/1000, Loss: 0.0072
# Epoch 400/1000, Loss: 0.0045
# Epoch 500/1000, Loss: 0.0034
# Epoch 600/1000, Loss: 0.0070
# Epoch 700/1000, Loss: 0.0070
# Epoch 800/1000, Loss: 0.0087
# Epoch 900/1000, Loss: 0.0028
# Epoch 1000/1000, Loss: 0.0029
# 	Validation loss = 0.0030831668991595507
# -----Fold: 2-----
# Epoch 100/1000, Loss: 0.0585
# Epoch 200/1000, Loss: 0.0181
# Epoch 300/1000, Loss: 0.0102
# Epoch 400/1000, Loss: 0.0046
# Epoch 500/1000, Loss: 0.0226
# Epoch 600/1000, Loss: 0.0045
# Epoch 700/1000, Loss: 0.0120
# Epoch 800/1000, Loss: 0.0145
# Epoch 900/1000, Loss: 0.0198
# Epoch 1000/1000, Loss: 0.0019
# 	Validation loss = 0.005060398951172829
# -----Fold: 3-----
# Epoch 100/1000, Loss: 0.4621
# Epoch 200/1000, Loss: 0.0266
# Epoch 300/1000, Loss: 0.0098
# Epoch 400/1000, Loss: 0.0050
# Epoch 500/1000, Loss: 0.0039
# Epoch 600/1000, Loss: 0.0035
# Epoch 700/1000, Loss: 0.0032
# Epoch 800/1000, Loss: 0.0050
# Epoch 900/1000, Loss: 0.0018
# Epoch 1000/1000, Loss: 0.0021
# 	Validation loss = 0.0023204032331705093
# -----Fold: 4-----
# Epoch 100/1000, Loss: 0.0634
# Epoch 200/1000, Loss: 0.0162
# Epoch 300/1000, Loss: 0.0135
# Epoch 400/1000, Loss: 0.0068
# Epoch 500/1000, Loss: 0.0084
# Epoch 600/1000, Loss: 0.0026
# Epoch 700/1000, Loss: 0.0057
# Epoch 800/1000, Loss: 0.0024
# Epoch 900/1000, Loss: 0.0018
# Epoch 1000/1000, Loss: 0.0020
# 	Validation loss = 0.002473947126418352
# -----Fold: 5-----
# Epoch 100/1000, Loss: 0.0570
# Epoch 200/1000, Loss: 0.0447
# Epoch 300/1000, Loss: 0.0079
# Epoch 400/1000, Loss: 0.0065
# Epoch 500/1000, Loss: 0.0031
# Epoch 600/1000, Loss: 0.0027
# Epoch 700/1000, Loss: 0.0079
# Epoch 800/1000, Loss: 0.0028
# Epoch 900/1000, Loss: 0.0067
# Epoch 1000/1000, Loss: 0.0022
# 	Validation loss = 0.004035811871290207

# %%
best_model, best_loss
# Out:
# (HarmonicModel3(
#    (layers): ModuleList(
#      (0): Linear(in_features=4, out_features=60, bias=True)
#      (1-5): 5 x Linear(in_features=60, out_features=60, bias=True)
#      (6): Linear(in_features=60, out_features=1, bias=True)
#    )
#  ),
#  0.0023204032331705093)

# %%
# test dataset
best_model.eval()
X = test3["X"]
y_exp = test3["y_tensor"][0:, 0:, 0].to(device)
y_pred = best_model(X).squeeze(-1)
t = X[0:, 0:, 3]
k = X[0:, 0:, 0]
x_00 = X[0:, 0:, 1]
x_01 = X[0:, 0:, 2]
#print(T_pred_test)
test_loss = loss_PINN3(best_model, y_pred, y_exp, x_00, x_01, t, k, N_f=100, l_y=1, l_f=1)
print(f"Test Loss: {test_loss.item():.4f}")
# Out:
# Test Loss: 0.0107

# %%
print(y_pred.shape)
y_pred.to("cpu")
test3["t_tensor"].to("cpu")

n = 30
plt.scatter(test3["t_tensor"][n], test3["y_tensor"][n][0:, 0], label="True Data")
plt.plot(test3["t_tensor"][n], y_pred.cpu().detach()[n], color="red", label="Predictions")
plt.legend()
plt.show()
# Out:
# torch.Size([300, 100])

# %% [markdown]
# ## Optimizing hyperparameters

# %% [markdown]
# Some of the parameters are held constant to minimize the number of iterations (they won't be kept constant for the final work)

# %%
def objective(trial):

    #Model hyperparemeters
    n_hidden_layers = trial.suggest_int("n_hidden_layers", 1, 10)
    hidden_neurons = [trial.suggest_int(f"n_neurons{i}", 1, 256, log=True) for i in range(n_hidden_layers)]
    activation = trial.suggest_categorical("activation", ["tanh", "sine", "relu", "gelu"])
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)

    #Loss function hyperparameters
    l_y = trial.suggest_float("l_y", 0.1, 10.0, log=True)
    l_f = trial.suggest_float("l_f", 0.1, 10.0, log=True)
    N_f = trial.suggest_int("N_f", 50, 300) #to change

    #Training hyperparameters
    epochs = trial.suggest_int("epochs", 10, 200) #to change
    n_splits = trial.suggest_int("n_splits", 2, 10)
    optimizers = [torch.optim.Adam, torch.optim.SGD, 
                  torch.optim.RMSprop, torch.optim.Adagrad,
                  torch.optim.ASGD, torch.optim.Rprop]
    optimizer_idx = trial.suggest_int("optimizer_idx", 0, len(optimizers) - 1)
    optimizer_class = optimizers[optimizer_idx]

    model_args = (4, n_hidden_layers, hidden_neurons, activation)

    #Training using K-fold
    best_model, best_loss = train_PINN3(
        model_class=HarmonicModel3,
        model_args=model_args,
        n_splits=5,
        l_y=1,
        l_f=1,
        optimizer_class=optimizer_class,
        lr=0.01,
        epochs=50,
        N_f=100,
        data=train3,
        random_state=trial.number,
        show_progress=False
    )

    return best_loss

# %%
study = optuna.create_study(
    sampler=optuna.samplers.TPESampler(seed=0),
    study_name="PINN_harmonic_oscillator",
    direction="minimize",
    pruner=optuna.pruners.MedianPruner(n_startup_trials=2, n_warmup_steps=10)
)

study.optimize(objective, n_trials=50, n_jobs=1, show_progress_bar=True)
# Out:
# [I 2025-11-19 17:20:43,178] A new study created in memory with name: PINN_harmonic_oscillator
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-19 17:20:46,921] Trial 0 finished with value: 0.7033476233482361 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 43, 'n_neurons1': 22, 'n_neurons2': 15, 'n_neurons3': 7, 'n_neurons4': 28, 'n_neurons5': 8, 'activation': 'sine', 'lr': 0.001304907355036239, 'l_y': 1.3680095279726923, 'l_f': 7.098936257405906, 'N_f': 67, 'epochs': 26, 'n_splits': 2, 'optimizer_idx': 4}. Best is trial 0 with value: 0.7033476233482361.
# [I 2025-11-19 17:20:57,641] Trial 1 finished with value: 0.641829252243042 and parameters: {'n_hidden_layers': 8, 'n_neurons0': 114, 'n_neurons1': 224, 'n_neurons2': 73, 'n_neurons3': 9, 'n_neurons4': 65, 'n_neurons5': 1, 'n_neurons6': 27, 'n_neurons7': 1, 'activation': 'tanh', 'lr': 0.01250071223083625, 'l_y': 0.8171478915115865, 'l_f': 1.3704648392849021, 'N_f': 54, 'epochs': 127, 'n_splits': 7, 'optimizer_idx': 3}. Best is trial 1 with value: 0.641829252243042.
# [I 2025-11-19 17:21:03,533] Trial 2 finished with value: 0.7352241277694702 and parameters: {'n_hidden_layers': 10, 'n_neurons0': 35, 'n_neurons1': 5, 'n_neurons2': 8, 'n_neurons3': 39, 'n_neurons4': 1, 'n_neurons5': 32, 'n_neurons6': 33, 'n_neurons7': 2, 'n_neurons8': 1, 'n_neurons9': 4, 'activation': 'gelu', 'lr': 2.559642090152664e-05, 'l_y': 0.26166974560854467, 'l_f': 0.21019338091154413, 'N_f': 213, 'epochs': 58, 'n_splits': 6, 'optimizer_idx': 1}. Best is trial 1 with value: 0.641829252243042.
# [I 2025-11-19 17:21:05,152] Trial 3 finished with value: 0.6711881160736084 and parameters: {'n_hidden_layers': 2, 'n_neurons0': 1, 'n_neurons1': 30, 'activation': 'gelu', 'lr': 2.445710810231886e-05, 'l_y': 4.741216804249709, 'l_f': 0.15566709318481198, 'N_f': 295, 'epochs': 99, 'n_splits': 10, 'optimizer_idx': 3}. Best is trial 1 with value: 0.641829252243042.
# [I 2025-11-19 17:21:09,352] Trial 4 finished with value: 0.7028469443321228 and parameters: {'n_hidden_layers': 8, 'n_neurons0': 1, 'n_neurons1': 3, 'n_neurons2': 1, 'n_neurons3': 3, 'n_neurons4': 1, 'n_neurons5': 4, 'n_neurons6': 7, 'n_neurons7': 1, 'activation': 'tanh', 'lr': 2.3755383341274175e-05, 'l_y': 1.418707913147324, 'l_f': 7.220917699605245, 'N_f': 129, 'epochs': 137, 'n_splits': 3, 'optimizer_idx': 4}. Best is trial 1 with value: 0.641829252243042.
# [I 2025-11-19 17:21:11,247] Trial 5 finished with value: 0.7992784380912781 and parameters: {'n_hidden_layers': 3, 'n_neurons0': 2, 'n_neurons1': 19, 'n_neurons2': 1, 'activation': 'tanh', 'lr': 0.008725214019150636, 'l_y': 8.401891913442235, 'l_f': 0.31441719363595283, 'N_f': 194, 'epochs': 123, 'n_splits': 7, 'optimizer_idx': 1}. Best is trial 1 with value: 0.641829252243042.
# [I 2025-11-19 17:21:16,503] Trial 6 finished with value: 0.6266588568687439 and parameters: {'n_hidden_layers': 10, 'n_neurons0': 8, 'n_neurons1': 98, 'n_neurons2': 39, 'n_neurons3': 3, 'n_neurons4': 80, 'n_neurons5': 6, 'n_neurons6': 122, 'n_neurons7': 19, 'n_neurons8': 123, 'n_neurons9': 38, 'activation': 'relu', 'lr': 0.0004959297871778077, 'l_y': 1.6322490640824154, 'l_f': 0.10924118351371671, 'N_f': 125, 'epochs': 136, 'n_splits': 4, 'optimizer_idx': 3}. Best is trial 6 with value: 0.6266588568687439.
# [I 2025-11-19 17:21:19,810] Trial 7 finished with value: 0.45412540435791016 and parameters: {'n_hidden_layers': 5, 'n_neurons0': 1, 'n_neurons1': 3, 'n_neurons2': 18, 'n_neurons3': 20, 'n_neurons4': 18, 'activation': 'gelu', 'lr': 0.00029528914353799785, 'l_y': 0.7442688632875935, 'l_f': 6.079203898818127, 'N_f': 252, 'epochs': 144, 'n_splits': 2, 'optimizer_idx': 5}. Best is trial 7 with value: 0.45412540435791016.
# [I 2025-11-19 17:21:34,918] Trial 8 finished with value: 0.693352997303009 and parameters: {'n_hidden_layers': 8, 'n_neurons0': 255, 'n_neurons1': 1, 'n_neurons2': 113, 'n_neurons3': 1, 'n_neurons4': 23, 'n_neurons5': 1, 'n_neurons6': 99, 'n_neurons7': 77, 'activation': 'gelu', 'lr': 0.0006518846138733343, 'l_y': 2.7804250906328947, 'l_f': 5.404613626296213, 'N_f': 294, 'epochs': 173, 'n_splits': 2, 'optimizer_idx': 2}. Best is trial 7 with value: 0.45412540435791016.
# [I 2025-11-19 17:21:38,754] Trial 9 finished with value: 0.7032527327537537 and parameters: {'n_hidden_layers': 8, 'n_neurons0': 1, 'n_neurons1': 13, 'n_neurons2': 1, 'n_neurons3': 2, 'n_neurons4': 1, 'n_neurons5': 71, 'n_neurons6': 2, 'n_neurons7': 4, 'activation': 'tanh', 'lr': 0.0030613543792987557, 'l_y': 1.4271091058141991, 'l_f': 0.29907880915878116, 'N_f': 284, 'epochs': 127, 'n_splits': 6, 'optimizer_idx': 3}. Best is trial 7 with value: 0.45412540435791016.
# [I 2025-11-19 17:21:41,139] Trial 10 finished with value: 0.34754177927970886 and parameters: {'n_hidden_layers': 4, 'n_neurons0': 5, 'n_neurons1': 1, 'n_neurons2': 8, 'n_neurons3': 187, 'activation': 'relu', 'lr': 0.00017123553109627275, 'l_y': 0.24360766874733958, 'l_f': 1.9841523307337057, 'N_f': 236, 'epochs': 187, 'n_splits': 10, 'optimizer_idx': 5}. Best is trial 10 with value: 0.34754177927970886.
# [I 2025-11-19 17:21:43,600] Trial 11 finished with value: 0.47315144538879395 and parameters: {'n_hidden_layers': 4, 'n_neurons0': 5, 'n_neurons1': 1, 'n_neurons2': 6, 'n_neurons3': 200, 'activation': 'relu', 'lr': 0.00015506187766099996, 'l_y': 0.1037163493293723, 'l_f': 2.0360221188534116, 'N_f': 238, 'epochs': 197, 'n_splits': 10, 'optimizer_idx': 5}. Best is trial 10 with value: 0.34754177927970886.
# [I 2025-11-19 17:21:46,037] Trial 12 finished with value: 0.37243086099624634 and parameters: {'n_hidden_layers': 5, 'n_neurons0': 3, 'n_neurons1': 2, 'n_neurons2': 4, 'n_neurons3': 71, 'n_neurons4': 7, 'activation': 'relu', 'lr': 0.000201175363611556, 'l_y': 0.3891057908306377, 'l_f': 2.955280776734045, 'N_f': 238, 'epochs': 171, 'n_splits': 8, 'optimizer_idx': 5}. Best is trial 10 with value: 0.34754177927970886.
# [I 2025-11-19 17:21:47,186] Trial 13 finished with value: 0.45330989360809326 and parameters: {'n_hidden_layers': 1, 'n_neurons0': 4, 'activation': 'relu', 'lr': 0.05998608317596316, 'l_y': 0.3085860200424443, 'l_f': 2.6446504578365237, 'N_f': 160, 'epochs': 198, 'n_splits': 9, 'optimizer_idx': 5}. Best is trial 10 with value: 0.34754177927970886.
# [I 2025-11-19 17:21:51,411] Trial 14 finished with value: 0.6339247822761536 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 15, 'n_neurons1': 1, 'n_neurons2': 3, 'n_neurons3': 249, 'n_neurons4': 5, 'n_neurons5': 179, 'activation': 'relu', 'lr': 9.542135998923302e-05, 'l_y': 0.3271098747688551, 'l_f': 0.7287844924105715, 'N_f': 240, 'epochs': 171, 'n_splits': 8, 'optimizer_idx': 4}. Best is trial 10 with value: 0.34754177927970886.
# [I 2025-11-19 17:21:54,189] Trial 15 finished with value: 0.5203106999397278 and parameters: {'n_hidden_layers': 5, 'n_neurons0': 3, 'n_neurons1': 5, 'n_neurons2': 3, 'n_neurons3': 58, 'n_neurons4': 218, 'activation': 'relu', 'lr': 9.100814123943191e-05, 'l_y': 0.12767255098935107, 'l_f': 0.6793945766005465, 'N_f': 168, 'epochs': 167, 'n_splits': 9, 'optimizer_idx': 0}. Best is trial 10 with value: 0.34754177927970886.
# [I 2025-11-19 17:21:58,319] Trial 16 finished with value: 0.18706120550632477 and parameters: {'n_hidden_layers': 3, 'n_neurons0': 15, 'n_neurons1': 2, 'n_neurons2': 245, 'activation': 'sine', 'lr': 0.001900144527978993, 'l_y': 0.5100429667780377, 'l_f': 3.206929719194828, 'N_f': 260, 'epochs': 90, 'n_splits': 8, 'optimizer_idx': 5}. Best is trial 16 with value: 0.18706120550632477.
# [I 2025-11-19 17:22:02,078] Trial 17 finished with value: 0.7313318252563477 and parameters: {'n_hidden_layers': 3, 'n_neurons0': 17, 'n_neurons1': 7, 'n_neurons2': 208, 'activation': 'sine', 'lr': 0.0018670558905982862, 'l_y': 0.16996383881805674, 'l_f': 1.3532405471378894, 'N_f': 262, 'epochs': 88, 'n_splits': 5, 'optimizer_idx': 4}. Best is trial 16 with value: 0.18706120550632477.
# [I 2025-11-19 17:22:03,271] Trial 18 finished with value: 0.21361812949180603 and parameters: {'n_hidden_layers': 1, 'n_neurons0': 34, 'activation': 'sine', 'lr': 0.0054725822205515355, 'l_y': 0.5391803631822703, 'l_f': 3.622478898808944, 'N_f': 203, 'epochs': 71, 'n_splits': 9, 'optimizer_idx': 5}. Best is trial 16 with value: 0.18706120550632477.
# [I 2025-11-19 17:22:04,322] Trial 19 finished with value: 0.4623652398586273 and parameters: {'n_hidden_layers': 1, 'n_neurons0': 36, 'activation': 'sine', 'lr': 0.009169785970364904, 'l_y': 0.5442970311417629, 'l_f': 4.034538479723855, 'N_f': 208, 'epochs': 74, 'n_splits': 8, 'optimizer_idx': 2}. Best is trial 16 with value: 0.18706120550632477.
# [I 2025-11-19 17:22:06,967] Trial 20 finished with value: 0.7051633596420288 and parameters: {'n_hidden_layers': 2, 'n_neurons0': 65, 'n_neurons1': 57, 'activation': 'sine', 'lr': 0.03368322605192531, 'l_y': 0.48748647834241665, 'l_f': 9.410337933623671, 'N_f': 141, 'epochs': 41, 'n_splits': 9, 'optimizer_idx': 4}. Best is trial 16 with value: 0.18706120550632477.
# [I 2025-11-19 17:22:09,256] Trial 21 finished with value: 0.2500785291194916 and parameters: {'n_hidden_layers': 3, 'n_neurons0': 8, 'n_neurons1': 2, 'n_neurons2': 30, 'activation': 'sine', 'lr': 0.004805109777859614, 'l_y': 0.19955237014405622, 'l_f': 1.8644014580958772, 'N_f': 214, 'epochs': 65, 'n_splits': 10, 'optimizer_idx': 5}. Best is trial 16 with value: 0.18706120550632477.
# [I 2025-11-19 17:22:10,974] Trial 22 finished with value: 0.16973093152046204 and parameters: {'n_hidden_layers': 2, 'n_neurons0': 21, 'n_neurons1': 2, 'activation': 'sine', 'lr': 0.004536420623420342, 'l_y': 0.16174683246450777, 'l_f': 3.8829897428534133, 'N_f': 191, 'epochs': 61, 'n_splits': 9, 'optimizer_idx': 5}. Best is trial 22 with value: 0.16973093152046204.
# [I 2025-11-19 17:22:12,616] Trial 23 finished with value: 0.5605546236038208 and parameters: {'n_hidden_layers': 2, 'n_neurons0': 22, 'n_neurons1': 9, 'activation': 'sine', 'lr': 0.028096432683323996, 'l_y': 0.5752427940372908, 'l_f': 4.010433434547178, 'N_f': 189, 'epochs': 43, 'n_splits': 7, 'optimizer_idx': 4}. Best is trial 22 with value: 0.16973093152046204.
# [I 2025-11-19 17:22:13,944] Trial 24 finished with value: 0.18729974329471588 and parameters: {'n_hidden_layers': 1, 'n_neurons0': 69, 'activation': 'sine', 'lr': 0.003535692094555831, 'l_y': 0.1397642364859231, 'l_f': 3.8504037044064483, 'N_f': 100, 'epochs': 85, 'n_splits': 9, 'optimizer_idx': 5}. Best is trial 22 with value: 0.16973093152046204.
# [I 2025-11-19 17:22:16,345] Trial 25 finished with value: 0.0892581045627594 and parameters: {'n_hidden_layers': 2, 'n_neurons0': 97, 'n_neurons1': 2, 'activation': 'sine', 'lr': 0.002158878241969923, 'l_y': 0.1521114718550403, 'l_f': 9.664145242175925, 'N_f': 94, 'epochs': 105, 'n_splits': 8, 'optimizer_idx': 5}. Best is trial 25 with value: 0.0892581045627594.
# [I 2025-11-19 17:22:25,728] Trial 26 finished with value: 0.5734403133392334 and parameters: {'n_hidden_layers': 4, 'n_neurons0': 242, 'n_neurons1': 2, 'n_neurons2': 231, 'n_neurons3': 1, 'activation': 'sine', 'lr': 0.0017818715772483023, 'l_y': 0.19595927906023666, 'l_f': 9.446223902904169, 'N_f': 107, 'epochs': 105, 'n_splits': 8, 'optimizer_idx': 4}. Best is trial 25 with value: 0.0892581045627594.
# [I 2025-11-19 17:22:28,459] Trial 27 finished with value: 0.10035907477140427 and parameters: {'n_hidden_layers': 2, 'n_neurons0': 121, 'n_neurons1': 3, 'activation': 'sine', 'lr': 0.0007022031668108069, 'l_y': 0.10593640215990548, 'l_f': 5.253457296826728, 'N_f': 93, 'epochs': 19, 'n_splits': 7, 'optimizer_idx': 5}. Best is trial 25 with value: 0.0892581045627594.
# [I 2025-11-19 17:22:31,497] Trial 28 finished with value: 0.7044154405593872 and parameters: {'n_hidden_layers': 2, 'n_neurons0': 135, 'n_neurons1': 4, 'activation': 'sine', 'lr': 0.0007531315721819474, 'l_y': 0.10552038541344606, 'l_f': 5.1639662158669175, 'N_f': 89, 'epochs': 10, 'n_splits': 5, 'optimizer_idx': 4}. Best is trial 25 with value: 0.0892581045627594.
# [I 2025-11-19 17:22:36,408] Trial 29 finished with value: 0.04489496350288391 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 141, 'n_neurons1': 7, 'n_neurons2': 2, 'n_neurons3': 27, 'n_neurons4': 3, 'n_neurons5': 33, 'activation': 'sine', 'lr': 0.001242523266506932, 'l_y': 0.18394712287989004, 'l_f': 7.290629349803258, 'N_f': 76, 'epochs': 12, 'n_splits': 7, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:22:41,372] Trial 30 finished with value: 0.6828703880310059 and parameters: {'n_hidden_layers': 7, 'n_neurons0': 142, 'n_neurons1': 8, 'n_neurons2': 2, 'n_neurons3': 20, 'n_neurons4': 3, 'n_neurons5': 42, 'n_neurons6': 1, 'activation': 'sine', 'lr': 0.00037554032580332, 'l_y': 0.2303139091979267, 'l_f': 7.5968304935458555, 'N_f': 74, 'epochs': 14, 'n_splits': 5, 'optimizer_idx': 2}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:22:45,975] Trial 31 finished with value: 0.09247449040412903 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 66, 'n_neurons1': 3, 'n_neurons2': 2, 'n_neurons3': 88, 'n_neurons4': 3, 'n_neurons5': 20, 'activation': 'sine', 'lr': 0.0011500441875033811, 'l_y': 0.15363375487949704, 'l_f': 5.588035138766146, 'N_f': 73, 'epochs': 33, 'n_splits': 7, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:22:51,288] Trial 32 finished with value: 0.12224147468805313 and parameters: {'n_hidden_layers': 7, 'n_neurons0': 80, 'n_neurons1': 4, 'n_neurons2': 2, 'n_neurons3': 99, 'n_neurons4': 2, 'n_neurons5': 19, 'n_neurons6': 4, 'activation': 'sine', 'lr': 0.0010318522400254672, 'l_y': 0.10035808245479788, 'l_f': 7.225063309536347, 'N_f': 52, 'epochs': 30, 'n_splits': 7, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:00,811] Trial 33 finished with value: 0.7263340950012207 and parameters: {'n_hidden_layers': 7, 'n_neurons0': 99, 'n_neurons1': 12, 'n_neurons2': 2, 'n_neurons3': 31, 'n_neurons4': 3, 'n_neurons5': 114, 'n_neurons6': 223, 'activation': 'sine', 'lr': 0.0011744462369808204, 'l_y': 0.1394705823060658, 'l_f': 9.77463964034987, 'N_f': 74, 'epochs': 23, 'n_splits': 6, 'optimizer_idx': 4}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:05,637] Trial 34 finished with value: 0.07714347541332245 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 54, 'n_neurons1': 6, 'n_neurons2': 5, 'n_neurons3': 108, 'n_neurons4': 8, 'n_neurons5': 17, 'activation': 'sine', 'lr': 0.002306980643528984, 'l_y': 0.3106010955542156, 'l_f': 5.019047916565313, 'N_f': 65, 'epochs': 44, 'n_splits': 7, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:10,392] Trial 35 finished with value: 0.48918232321739197 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 52, 'n_neurons1': 18, 'n_neurons2': 5, 'n_neurons3': 107, 'n_neurons4': 9, 'n_neurons5': 19, 'activation': 'sine', 'lr': 0.016359708385027934, 'l_y': 0.33318022693877075, 'l_f': 6.476660077840969, 'N_f': 65, 'epochs': 48, 'n_splits': 6, 'optimizer_idx': 3}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:20,388] Trial 36 finished with value: 0.7970978617668152 and parameters: {'n_hidden_layers': 9, 'n_neurons0': 173, 'n_neurons1': 6, 'n_neurons2': 2, 'n_neurons3': 41, 'n_neurons4': 2, 'n_neurons5': 14, 'n_neurons6': 20, 'n_neurons7': 242, 'n_neurons8': 10, 'activation': 'tanh', 'lr': 0.0024678696595055445, 'l_y': 0.9748379348159029, 'l_f': 4.6946090026524745, 'N_f': 109, 'epochs': 32, 'n_splits': 7, 'optimizer_idx': 4}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:26,794] Trial 37 finished with value: 0.4361855387687683 and parameters: {'n_hidden_layers': 7, 'n_neurons0': 52, 'n_neurons1': 11, 'n_neurons2': 12, 'n_neurons3': 108, 'n_neurons4': 5, 'n_neurons5': 3, 'n_neurons6': 1, 'activation': 'gelu', 'lr': 0.0014504120792517047, 'l_y': 0.24874647623234616, 'l_f': 7.351553621184762, 'N_f': 82, 'epochs': 53, 'n_splits': 7, 'optimizer_idx': 0}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:29,981] Trial 38 finished with value: 0.7874709963798523 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 27, 'n_neurons1': 4, 'n_neurons2': 3, 'n_neurons3': 17, 'n_neurons4': 13, 'n_neurons5': 36, 'activation': 'sine', 'lr': 0.006590465742567239, 'l_y': 0.17832482681549006, 'l_f': 2.4725212328423183, 'N_f': 63, 'epochs': 34, 'n_splits': 6, 'optimizer_idx': 1}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:36,818] Trial 39 finished with value: 0.678043782711029 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 183, 'n_neurons1': 38, 'n_neurons2': 1, 'n_neurons3': 70, 'n_neurons4': 2, 'n_neurons5': 73, 'activation': 'tanh', 'lr': 0.016511220321644066, 'l_y': 2.1217248212880846, 'l_f': 1.0993903859481489, 'N_f': 121, 'epochs': 118, 'n_splits': 8, 'optimizer_idx': 4}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:50,954] Trial 40 finished with value: 0.5093129277229309 and parameters: {'n_hidden_layers': 5, 'n_neurons0': 96, 'n_neurons1': 213, 'n_neurons2': 15, 'n_neurons3': 132, 'n_neurons4': 4, 'activation': 'gelu', 'lr': 1.056045645472566e-05, 'l_y': 0.4132120176013996, 'l_f': 8.144022559743924, 'N_f': 148, 'epochs': 110, 'n_splits': 6, 'optimizer_idx': 3}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:54,970] Trial 41 finished with value: 0.09426810592412949 and parameters: {'n_hidden_layers': 5, 'n_neurons0': 121, 'n_neurons1': 3, 'n_neurons2': 7, 'n_neurons3': 30, 'n_neurons4': 10, 'activation': 'sine', 'lr': 0.0005124752644579333, 'l_y': 0.13841354077774412, 'l_f': 5.733151109278015, 'N_f': 94, 'epochs': 24, 'n_splits': 7, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:23:58,667] Trial 42 finished with value: 0.11204782873392105 and parameters: {'n_hidden_layers': 6, 'n_neurons0': 49, 'n_neurons1': 3, 'n_neurons2': 8, 'n_neurons3': 29, 'n_neurons4': 14, 'n_neurons5': 12, 'activation': 'sine', 'lr': 0.0004359650377699683, 'l_y': 0.1397637469126011, 'l_f': 6.238351462147672, 'N_f': 59, 'epochs': 23, 'n_splits': 7, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:24:07,674] Trial 43 finished with value: 0.08556544780731201 and parameters: {'n_hidden_layers': 9, 'n_neurons0': 185, 'n_neurons1': 6, 'n_neurons2': 4, 'n_neurons3': 13, 'n_neurons4': 10, 'n_neurons5': 27, 'n_neurons6': 9, 'n_neurons7': 11, 'n_neurons8': 219, 'activation': 'sine', 'lr': 0.0010126797728832065, 'l_y': 0.22097832378557242, 'l_f': 4.686748037637818, 'N_f': 83, 'epochs': 38, 'n_splits': 6, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:24:23,408] Trial 44 finished with value: 0.1595628410577774 and parameters: {'n_hidden_layers': 10, 'n_neurons0': 189, 'n_neurons1': 6, 'n_neurons2': 3, 'n_neurons3': 7, 'n_neurons4': 7, 'n_neurons5': 27, 'n_neurons6': 8, 'n_neurons7': 18, 'n_neurons8': 247, 'n_neurons9': 238, 'activation': 'sine', 'lr': 0.00267505080089189, 'l_y': 0.2672628625633338, 'l_f': 4.863012973374193, 'N_f': 50, 'epochs': 39, 'n_splits': 4, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:24:29,896] Trial 45 finished with value: 0.04539934918284416 and parameters: {'n_hidden_layers': 9, 'n_neurons0': 85, 'n_neurons1': 16, 'n_neurons2': 4, 'n_neurons3': 14, 'n_neurons4': 37, 'n_neurons5': 74, 'n_neurons6': 3, 'n_neurons7': 7, 'n_neurons8': 22, 'activation': 'sine', 'lr': 0.000905896936541512, 'l_y': 6.732918474683191, 'l_f': 8.716040590805392, 'N_f': 79, 'epochs': 54, 'n_splits': 6, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:24:38,004] Trial 46 finished with value: 0.1805829107761383 and parameters: {'n_hidden_layers': 9, 'n_neurons0': 219, 'n_neurons1': 24, 'n_neurons2': 4, 'n_neurons3': 12, 'n_neurons4': 52, 'n_neurons5': 61, 'n_neurons6': 4, 'n_neurons7': 7, 'n_neurons8': 23, 'activation': 'tanh', 'lr': 0.0002443198676357738, 'l_y': 5.702660551157148, 'l_f': 8.296699809980995, 'N_f': 113, 'epochs': 53, 'n_splits': 5, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:24:49,606] Trial 47 finished with value: 0.6666433811187744 and parameters: {'n_hidden_layers': 9, 'n_neurons0': 90, 'n_neurons1': 16, 'n_neurons2': 21, 'n_neurons3': 5, 'n_neurons4': 34, 'n_neurons5': 132, 'n_neurons6': 2, 'n_neurons7': 39, 'n_neurons8': 24, 'activation': 'gelu', 'lr': 0.0008040010368144135, 'l_y': 3.0201866671710604, 'l_f': 0.5577489023117235, 'N_f': 86, 'epochs': 75, 'n_splits': 6, 'optimizer_idx': 4}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:24:56,675] Trial 48 finished with value: 0.058947257697582245 and parameters: {'n_hidden_layers': 8, 'n_neurons0': 148, 'n_neurons1': 27, 'n_neurons2': 11, 'n_neurons3': 11, 'n_neurons4': 34, 'n_neurons5': 52, 'n_neurons6': 15, 'n_neurons7': 6, 'activation': 'sine', 'lr': 0.00010091426108069393, 'l_y': 7.9207786597232515, 'l_f': 9.845128798774908, 'N_f': 138, 'epochs': 50, 'n_splits': 4, 'optimizer_idx': 5}. Best is trial 29 with value: 0.04489496350288391.
# [I 2025-11-19 17:25:04,245] Trial 49 finished with value: 0.04108443111181259 and parameters: {'n_hidden_layers': 8, 'n_neurons0': 151, 'n_neurons1': 42, 'n_neurons2': 12, 'n_neurons3': 12, 'n_neurons4': 33, 'n_neurons5': 53, 'n_neurons6': 15, 'n_neurons7': 7, 'activation': 'sine', 'lr': 4.35507477553381e-05, 'l_y': 8.719230493634457, 'l_f': 2.408612558192758, 'N_f': 132, 'epochs': 51, 'n_splits': 4, 'optimizer_idx': 5}. Best is trial 49 with value: 0.04108443111181259.

# %%
print("Best hyperparameters:", study.best_trial.params)
print("Best value:", study.best_value)
# Out:
# Best hyperparameters: {'n_hidden_layers': 8, 'n_neurons0': 151, 'n_neurons1': 42, 'n_neurons2': 12, 'n_neurons3': 12, 'n_neurons4': 33, 'n_neurons5': 53, 'n_neurons6': 15, 'n_neurons7': 7, 'activation': 'sine', 'lr': 4.35507477553381e-05, 'l_y': 8.719230493634457, 'l_f': 2.408612558192758, 'N_f': 132, 'epochs': 51, 'n_splits': 4, 'optimizer_idx': 5}
# Best value: 0.04108443111181259

# %% [markdown]
# ## Testing new best hyperparameters

# %%
torch.cuda.empty_cache()

best_model_new, best_loss_new = train_PINN3(HarmonicModel3, 
                                    (4, 8, [151, 42, 12, 12, 33, 53, 15, 7], 'sine'), 
                                    n_splits=5,
                                    l_y=1,
                                    l_f=1,
                                    optimizer_class=torch.optim.Rprop, 
                                    lr=0.01, 
                                    epochs=1000, 
                                    N_f=100, 
                                    data=train3, 
                                    random_state=0,
                                    show_progress=True
                                   )
# Out:
# -----Fold: 1-----
# Epoch 100/1000, Loss: 0.0125
# Epoch 200/1000, Loss: 0.0047
# Epoch 300/1000, Loss: 0.0030
# Epoch 400/1000, Loss: 0.0024
# Epoch 500/1000, Loss: 0.0021
# Epoch 600/1000, Loss: 0.0019
# Epoch 700/1000, Loss: 0.0018
# Epoch 800/1000, Loss: 0.0017
# Epoch 900/1000, Loss: 0.0016
# Epoch 1000/1000, Loss: 0.0015
# 	Validation loss = 0.00189915020018816
# -----Fold: 2-----
# Epoch 100/1000, Loss: 0.0140
# Epoch 200/1000, Loss: 0.0047
# Epoch 300/1000, Loss: 0.0029
# Epoch 400/1000, Loss: 0.0023
# Epoch 500/1000, Loss: 0.0020
# Epoch 600/1000, Loss: 0.0019
# Epoch 700/1000, Loss: 0.0018
# Epoch 800/1000, Loss: 0.0017
# Epoch 900/1000, Loss: 0.0016
# Epoch 1000/1000, Loss: 0.0016
# 	Validation loss = 0.0026061441749334335
# -----Fold: 3-----
# Epoch 100/1000, Loss: 0.0149
# Epoch 200/1000, Loss: 0.0052
# Epoch 300/1000, Loss: 0.0037
# Epoch 400/1000, Loss: 0.0031
# Epoch 500/1000, Loss: 0.0028
# Epoch 600/1000, Loss: 0.0025
# Epoch 700/1000, Loss: 0.0022
# Epoch 800/1000, Loss: 0.0018
# Epoch 900/1000, Loss: 0.0016
# Epoch 1000/1000, Loss: 0.0014
# 	Validation loss = 0.001457691309042275
# -----Fold: 4-----
# Epoch 100/1000, Loss: 0.0132
# Epoch 200/1000, Loss: 0.0052
# Epoch 300/1000, Loss: 0.0037
# Epoch 400/1000, Loss: 0.0030
# Epoch 500/1000, Loss: 0.0027
# Epoch 600/1000, Loss: 0.0024
# Epoch 700/1000, Loss: 0.0023
# Epoch 800/1000, Loss: 0.0021
# Epoch 900/1000, Loss: 0.0020
# Epoch 1000/1000, Loss: 0.0019
# 	Validation loss = 0.002908017486333847
# -----Fold: 5-----
# Epoch 100/1000, Loss: 0.0114
# Epoch 200/1000, Loss: 0.0043
# Epoch 300/1000, Loss: 0.0029
# Epoch 400/1000, Loss: 0.0024
# Epoch 500/1000, Loss: 0.0021
# Epoch 600/1000, Loss: 0.0019
# Epoch 700/1000, Loss: 0.0017
# Epoch 800/1000, Loss: 0.0016
# Epoch 900/1000, Loss: 0.0016
# Epoch 1000/1000, Loss: 0.0015
# 	Validation loss = 0.0017589033814147115

# %%
best_model_new, best_loss_new
# Out:
# (HarmonicModel3(
#    (layers): ModuleList(
#      (0): Linear(in_features=4, out_features=151, bias=True)
#      (1): Linear(in_features=151, out_features=42, bias=True)
#      (2): Linear(in_features=42, out_features=12, bias=True)
#      (3): Linear(in_features=12, out_features=12, bias=True)
#      (4): Linear(in_features=12, out_features=33, bias=True)
#      (5): Linear(in_features=33, out_features=53, bias=True)
#      (6): Linear(in_features=53, out_features=15, bias=True)
#      (7): Linear(in_features=15, out_features=7, bias=True)
#      (8): Linear(in_features=7, out_features=1, bias=True)
#    )
#  ),
#  0.001457691309042275)

# %%
# test dataset
best_model_new.eval()
X = test3["X"]
y_exp = test3["y_tensor"][0:, 0:, 0].to(device)
y_pred = best_model_new(X).squeeze(-1)
t = X[0:, 0:, 3]
k = X[0:, 0:, 0]
x_00 = X[0:, 0:, 1]
x_01 = X[0:, 0:, 2]
#print(T_pred_test)
test_loss = loss_PINN3(best_model_new, y_pred, y_exp, x_00, x_01, t, k, N_f=100, l_y=1, l_f=1)
print(f"Test Loss: {test_loss.item():.4f}")
# Out:
# Test Loss: 0.0038

# %%
print(y_pred.shape)
y_pred.to("cpu")
test3["t_tensor"].to("cpu")

n = 30
plt.scatter(test3["t_tensor"][n], test3["y_tensor"][n][0:, 0], label="True Data")
plt.plot(test3["t_tensor"][n], y_pred.cpu().detach()[n], color="red", label="Predictions")
plt.legend()
plt.show()
# Out:
# torch.Size([300, 100])
